# %%
# run this at the beginning of the class to load all dependancies 
# (you can run things with Shift+Enter keyboard shortcut, or with the RUN button above)

import networkx as nx
import matplotlib.pyplot as plt
import os
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pprint as pp
import requests
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# # Assessment Preparation Challenge
#
# - These challenges are optional, are not marked and are just for you.
# - But they will prepare you for the course's final assesment. If you complete all of the challenges, you will have a much easier time doing the final assesment.
# - you will not be given answers to them, because large parts of the assesment will be very simmilar and if we gave you the answers you could copy-paste parts of it for assesment which would defeat the purpose of the assesment :)
#
#
# ### Challange 3: Given a twitter following of 'company X' what can you deduce from the data?
#
# `note that this exercise is highly exploratory and is rather about you playing with data, than achieving any particular goal.`
#
# Load and diagram the contents of the file 'anonymised_twitter_followers_of_company_x.csv' - it contains anonymised twitter followers of a certain data science related institution in Edinburgh. In the data the company we 'work for' is encoded as companyX.
#
# - look at the measurements, what can they tell you? Are some nodes more important? In what way?
# - what if you limit the data to just some subset of it?
# - can you try to program something you learned during the lectures about social networks?
#
# Use code from parts of code from this week's notebooks to help you.
#
#
# Have a look at the data. Format of the data is accound_id, followed by people who follow them (twitter calls it their 'friends').
#
# some_user_x, account_that_follows_x, another_account_that_follows_x, another_account_that_follows_x,
#
# So for example
# ```
# company_x,oyster_marshmallow,ruby_hogbean,cherry_basil
# dollar_meadowsweet,banana_marshmallow,cherry_basil
# cherry_basil,banana_marshmallow
# banana_marshmallow
# ```
#
# means that 3 accounts follow company_x. But no-one follows banana_marshmallow.
#
# # Note that this file is rather large (500 accounts) so generating even a simple graph will take a while. (a minute, or more)
#
# you might choose to filter it and keep only some accounts. (eg. the ones with company_x, or the ones with more followers than some number).

# %%
G = nx.read_adjlist('anonymised_twitter_followers_of_company_x.csv', delimiter=",", create_using=nx.DiGraph())
# note, without  create_using=nx.DiGraph() you might not see any edges at this scale

degree = nx.degree_centrality(G)
pp.pprint(degree)
# Out:
# {'alabaster_acacia': 0.2693877551020408,
#  'alabaster_foxglove': 0.16938775510204082,
#  'alabaster_hepatica': 0.08979591836734695,
#  'alabaster_marshmallow': 0.32040816326530613,
#  'amber_aloe': 0.20816326530612247,
#  'amber_bluebottle': 0.22244897959183677,
#  'amber_burdock': 0.20408163265306123,
#  'amber_foxglove': 0.08775510204081634,
#  'apple_ash': 0.32040816326530613,
#  'apple_bryony': 0.15510204081632656,
#  'apple_bugloss': 0.5510204081632654,
#  'apple_hyacinth': 0.3020408163265306,
#  'apple_milfoil': 0.19387755102040818,
#  'apple_motherwort': 0.2510204081632653,
#  'apple_mugwort': 0.08571428571428572,
#  'apricot_aloe': 0.45102040816326533,
#  'apricot_hornbeam': 0.4795918367346939,
#  'apricot_milfoil': 0.11224489795918369,
#  'apricot_milkwort': 0.22244897959183677,
#  'apricot_motherwort': 0.16122448979591839,
#  'banana_bramble': 0.21020408163265308,
#  'banana_fennel': 0.2448979591836735,
#  'banana_hollyhock': 0.4755102040816327,
#  'banana_honeysuckle': 0.48367346938775513,
#  'banana_hornbeam': 0.3816326530612245,
#  'banana_lilac': 0.10816326530612246,
#  'banana_marshmallow': 0.30000000000000004,
#  'banana_marvel': 0.1306122448979592,
#  'beige_acanthus': 0.3489795918367347,
#  'beige_burdock': 0.4612244897959184,
#  'beige_madder': 0.326530612244898,
#  'berry_aloe': 0.14489795918367349,
#  'berry_foxglove': 0.1489795918367347,
#  'berry_hedysarum': 0.1510204081632653,
#  'berry_helenium': 0.47755102040816333,
#  'berry_hogbean': 0.1653061224489796,
#  'biscotti_aloe': 0.23469387755102042,
#  'biscotti_ash': 0.1326530612244898,
#  'biscotti_blackthorn': 0.426530612244898,
#  'biscotti_bramble': 0.3285714285714286,
#  'biscotti_fieldrush': 0.3673469387755102,
#  'biscotti_hogbean': 0.20612244897959187,
#  'biscotti_honeysuckle': 0.40408163265306124,
#  'biscotti_laburnum': 0.11020408163265308,
#  'blonde_acacia': 0.42244897959183675,
#  'blonde_barberry': 0.11224489795918369,
#  'blonde_honesty': 0.1469387755102041,
#  'blood_basil': 0.7326530612244898,
#  'blood_laburnum': 0.3775510204081633,
#  'blood_meadowsweet': 0.17755102040816328,
#  'blood_mezereon': 0.1673469387755102,
#  'blush_fennel': 0.5081632653061225,
#  'blush_hollyhock': 0.18979591836734697,
#  'blush_larkspur': 0.33673469387755106,
#  'blush_lavender': 0.13673469387755102,
#  'bone_bluebottle': 0.1795918367346939,
#  'bone_bramble': 0.2755102040816327,
#  'bone_bugloss': 0.11836734693877551,
#  'bone_fennel': 0.489795918367347,
#  'bone_fieldrush': 0.13877551020408163,
#  'bone_holly': 0.2469387755102041,
#  'bone_lily': 0.2612244897959184,
#  'brick_fennel': 0.2755102040816327,
#  'brick_heath': 0.07959183673469389,
#  'brick_lavender': 0.26734693877551025,
#  'brick_manchineel': 0.2285714285714286,
#  'brick_mezereon': 0.17346938775510207,
#  'bronze_aloe': 0.22040816326530616,
#  'bronze_borage': 0.25918367346938775,
#  'bronze_holly': 0.10612244897959185,
#  'bronze_larch': 0.20816326530612247,
#  'bronze_madder': 0.11224489795918369,
#  'bumblebee_ash': 0.35714285714285715,
#  'bumblebee_lucerne': 0.1285714285714286,
#  'butter_laurel': 0.2,
#  'butter_meadowsweet': 0.1346938775510204,
#  'buttermilk_acacia': 0.12244897959183675,
#  'buttermilk_blackthorn': 0.489795918367347,
#  'buttermilk_bryony': 0.2163265306122449,
#  'buttermilk_bugloss': 0.3591836734693878,
#  'buttermilk_hyacinth': 0.20612244897959187,
#  'buttermilk_madder': 0.3102040816326531,
#  'buttermilk_milfoil': 0.489795918367347,
#  'butterscotch_acanthus': 0.02653061224489796,
#  'butterscotch_bellflower': 0.326530612244898,
#  'butterscotch_borage': 0.3755102040816327,
#  'butterscotch_milfoil': 0.326530612244898,
#  'canary_acacia': 0.10816326530612246,
#  'canary_acanthus': 0.31836734693877555,
#  'canary_bryony': 0.34693877551020413,
#  'canary_heath': 0.1673469387755102,
#  'canary_helenium': 0.05714285714285715,
#  'canary_honesty': 0.4571428571428572,
#  'canary_larkspur': 0.46938775510204084,
#  'canary_lily': 0.49591836734693884,
#  'canary_mezereon': 0.3346938775510204,
#  'candy_fieldrush': 0.28571428571428575,
#  'candy_hyacinth': 0.3591836734693878,
#  'cantaloupe_broom': 0.2306122448979592,
#  'cantaloupe_burdock': 0.21020408163265308,
#  'cantaloupe_larkspur': 0.13877551020408163,
#  'cantaloupe_milkwort': 0.07551020408163266,
#  'carrot_acacia': 0.07959183673469389,
#  'carrot_borage': 0.25918367346938775,
#  'carrot_bryony': 0.28163265306122454,
#  'carrot_hibiscus': 0.20408163265306123,
#  'carrot_lucerne': 0.3734693877551021,
#  'carrot_mandrake': 0.23673469387755103,
#  'carrot_meadowsweet': 0.2448979591836735,
#  'carrot_milkwort': 0.48775510204081635,
#  'cherry_basil': 0.2959183673469388,
#  'cherry_bugloss': 0.30612244897959184,
#  'cherry_hollyhock': 0.20816326530612247,
#  'cherry_lavender': 0.18775510204081636,
#  'chiffon_basil': 0.13877551020408163,
#  'chiffon_fieldrush': 0.326530612244898,
#  'chiffon_hedysarum': 0.326530612244898,
#  'chiffon_larch': 0.35714285714285715,
#  'cider_hortensia': 0.14489795918367349,
#  'cider_hyacinth': 0.10204081632653061,
#  'cider_manchineel': 0.2142857142857143,
#  'cider_meadow': 0.22040816326530616,
#  'cider_mugwort': 0.0979591836734694,
#  'clay_hedysarum': 0.5142857142857143,
#  'clay_hogbean': 0.22653061224489798,
#  'clay_lily': 0.3816326530612245,
#  'coconut_aloe': 0.0979591836734694,
#  'coconut_arum': 0.1959183673469388,
#  'coconut_ash': 0.3918367346938776,
#  'coconut_borage': 0.0836734693877551,
#  'coconut_lavender': 0.6959183673469388,
#  'company_x': 0.8142857142857144,
#  'corn_acacia': 0.9244897959183674,
#  'corn_angelica': 0.22244897959183677,
#  'corn_borage': 0.1142857142857143,
#  'corn_bramble': 0.04489795918367347,
#  'corn_hedysarum': 0.17551020408163268,
#  'corn_hyacinth': 0.13877551020408163,
#  'corn_lichen': 0.6653061224489797,
#  'corn_mandrake': 0.5020408163265306,
#  'cotton_hedysarum': 0.7183673469387756,
#  'cotton_helenium': 0.12653061224489798,
#  'cotton_honeysuckle': 0.35102040816326535,
#  'cotton_larch': 0.326530612244898,
#  'cotton_milfoil': 0.13877551020408163,
#  'cream_acanthus': 0.426530612244898,
#  'cream_hortensia': 0.13673469387755102,
#  'cream_larkspur': 0.15714285714285717,
#  'crimson_aloe': 0.1306122448979592,
#  'crimson_amaranth': 0.2306122448979592,
#  'crimson_barberry': 0.38979591836734695,
#  'crimson_hornbeam': 0.30000000000000004,
#  'crimson_marshmallow': 0.1326530612244898,
#  'crimson_mistletoe': 0.11836734693877551,
#  'currant_basil': 0.06938775510204082,
#  'currant_bramble': 0.1979591836734694,
#  'daffodil_borage': 0.2,
#  'daffodil_fennel': 0.26734693877551025,
#  'daffodil_foxglove': 0.11224489795918369,
#  'daffodil_marshmallow': 0.36530612244897964,
#  'daffodil_meadow': 0.16122448979591839,
#  'daisy_bryony': 0.2326530612244898,
#  'daisy_fig': 0.33877551020408164,
#  'daisy_hortensia': 0.4408163265306123,
#  'daisy_marigold': 0.2612244897959184,
#  'daisy_mezereon': 0.32244897959183677,
#  'daisy_motherwort': 0.25306122448979596,
#  'dandelion_bluebottle': 0.18979591836734697,
#  'dandelion_hepatica': 0.10816326530612246,
#  'dandelion_milkwort': 0.36938775510204086,
#  'dijon_aloe': 0.12448979591836735,
#  'dijon_bellflower': 0.1142857142857143,
#  'dijon_foxglove': 0.04489795918367347,
#  'dijon_hollow': 0.14285714285714288,
#  'dijon_marshmallow': 0.21836734693877552,
#  'dollar_barberry': 0.0020408163265306124,
#  'dollar_blackthorn': 0.2142857142857143,
#  'dollar_holly': 0.21836734693877552,
#  'dollar_hollyhock': 0.1489795918367347,
#  'dollar_honeysuckle': 0.10408163265306124,
#  'dollar_larch': 0.2448979591836735,
#  'dollar_larkspur': 0.2,
#  'dollar_lily': 0.7959183673469389,
#  'dollar_meadowsweet': 0.20408163265306123,
#  'dollar_myrtle': 0.3285714285714286,
#  'eggnog_arum': 0.06938775510204082,
#  'eggnog_fennel': 0.2285714285714286,
#  'eggnog_hepatica': 0.28571428571428575,
#  'eggnog_hogbean': 0.14081632653061227,
#  'eggnog_holly': 0.3306122448979592,
#  'eggnog_meadowsweet': 0.363265306122449,
#  'eggshell_aloe': 0.5938775510204082,
#  'eggshell_arum': 0.20408163265306123,
#  'eggshell_barberry': 0.0816326530612245,
#  'eggshell_helenium': 0.3020408163265306,
#  'eggshell_hepatica': 0.1816326530612245,
#  'eggshell_hibiscus': 0.0816326530612245,
#  'eggshell_lily': 0.12244897959183675,
#  'eggshell_mezereon': 0.17142857142857143,
#  'fawn_hazel': 0.263265306122449,
#  'fawn_hepatica': 0.1489795918367347,
#  'fawn_hibiscus': 0.11836734693877551,
#  'fire_acanthus': 0.1346938775510204,
#  'fire_aloe': 0.0489795918367347,
#  'fire_bugloss': 0.20612244897959187,
#  'fire_helenium': 0.05714285714285715,
#  'flaxen_ash': 0.31836734693877555,
#  'flaxen_blackthorn': 0.35102040816326535,
#  'flaxen_hedysarum': 0.2,
#  'flaxen_helenium': 0.17142857142857143,
#  'flaxen_laburnum': 0.13673469387755102,
#  'flaxen_laurel': 0.36530612244897964,
#  'frost_acacia': 0.07959183673469389,
#  'frost_lichen': 0.1489795918367347,
#  'frost_marigold': 0.27346938775510204,
#  'frost_meadow': 0.25918367346938775,
#  'garnet_acacia': 0.14081632653061227,
#  'garnet_bellflower': 0.4244897959183674,
#  'garnet_fennel': 0.2979591836734694,
#  'garnet_lilac': 0.11836734693877551,
#  'garnet_lucerne': 0.3102040816326531,
#  'ginger_angelica': 0.15306122448979592,
#  'ginger_blackthorn': 0.2571428571428572,
#  'ginger_borage': 0.16122448979591839,
#  'ginger_fennel': 0.2693877551020408,
#  'ginger_hollow': 0.33265306122448984,
#  'ginger_hyacinth': 0.46938775510204084,
#  'ginger_lichen': 0.3489795918367347,
#  'gold_ash': 0.1306122448979592,
#  'gold_hornbeam': 0.3755102040816327,
#  'gold_lavender': 0.16122448979591839,
#  'gold_lichen': 0.11836734693877551,
#  'gold_marshmallow': 0.1959183673469388,
#  'gold_mistletoe': 0.2571428571428572,
#  'granola_bryony': 0.4591836734693878,
#  'granola_hollow': 0.32040816326530613,
#  'granola_hortensia': 0.09591836734693879,
#  'granola_mandrake': 0.4469387755102041,
#  'granola_motherwort': 0.263265306122449,
#  'hazelnut_acanthus': 0.21836734693877552,
#  'hazelnut_hedysarum': 0.09387755102040818,
#  'hazelnut_mandrake': 0.5224489795918368,
#  'hazelnut_myrtle': 0.18571428571428572,
#  'hazelwood_arum': 0.11836734693877551,
#  'hazelwood_hazel': 0.2795918367346939,
#  'hazelwood_heath': 0.3448979591836735,
#  'hazelwood_larkspur': 0.11224489795918369,
#  'hazelwood_marigold': 0.4938775510204082,
#  'honey_fieldrush': 0.589795918367347,
#  'honey_lily': 0.13877551020408163,
#  'honey_madder': 0.23469387755102042,
#  'honey_mezereon': 0.15510204081632656,
#  'ivory_aloe': 0.23469387755102042,
#  'ivory_ash': 0.17551020408163268,
#  'ivory_bellflower': 0.17142857142857143,
#  'ivory_fig': 0.3102040816326531,
#  'ivory_foxglove': 0.05918367346938776,
#  'ivory_heath': 0.14081632653061227,
#  'ivory_motherwort': 0.18979591836734697,
#  'jam_fig': 0.2571428571428572,
#  'jam_hyacinth': 0.5142857142857143,
#  'jam_marigold': 0.3734693877551021,
#  'jam_marshmallow': 0.1653061224489796,
#  'lace_broom': 0.5857142857142857,
#  'lace_hibiscus': 0.1306122448979592,
#  'lace_manchineel': 0.14489795918367349,
#  'lace_marigold': 0.39795918367346944,
#  'lace_motherwort': 0.3755102040816327,
#  'lemon_acacia': 0.42040816326530617,
#  'lemon_acanthus': 0.28979591836734697,
#  'lemon_borage': 0.32244897959183677,
#  'lemon_hollyhock': 0.1653061224489796,
#  'lemon_lavender': 0.1285714285714286,
#  'lemon_madder': 0.1142857142857143,
#  'lemon_manchineel': 0.3734693877551021,
#  'lemon_mistletoe': 0.1979591836734694,
#  'linen_angelica': 0.33265306122448984,
#  'linen_fig': 0.5632653061224491,
#  'linen_milkwort': 0.7183673469387756,
#  'lipstick_bluebottle': 0.19387755102040818,
#  'lipstick_fieldrush': 0.21020408163265308,
#  'lipstick_larch': 0.2122448979591837,
#  'lipstick_manchineel': 0.25510204081632654,
#  'lipstick_mistletoe': 0.2571428571428572,
#  'lipstick_motherwort': 0.18571428571428572,
#  'macaroon_bugloss': 0.22448979591836737,
#  'macaroon_hortensia': 0.21836734693877552,
#  'macaroon_larkspur': 0.22448979591836737,
#  'macaroon_mezereon': 0.33265306122448984,
#  'macaroon_myrtle': 0.33673469387755106,
#  'mahogany_bramble': 0.2959183673469388,
#  'mahogany_bugloss': 0.1795918367346939,
#  'mahogany_hazel': 0.07142857142857144,
#  'mahogany_lilac': 0.11224489795918369,
#  'mahogany_mezereon': 0.3938775510204082,
#  'mahogany_milfoil': 0.14081632653061227,
#  'marigold_acacia': 0.13877551020408163,
#  'marigold_hogbean': 0.3122448979591837,
#  'marigold_meadowsweet': 0.35510204081632657,
#  'marmalade_bluebottle': 0.663265306122449,
#  'marmalade_lily': 0.28163265306122454,
#  'medallion_acanthus': 0.38979591836734695,
#  'medallion_amaranth': 0.2836734693877551,
#  'medallion_laurel': 0.13673469387755102,
#  'medallion_lilac': 0.1346938775510204,
#  'medallion_meadowsweet': 0.10612244897959185,
#  'medallion_milkwort': 0.1469387755102041,
#  'merlot_aloe': 0.17551020408163268,
#  'merlot_arum': 0.4,
#  'merlot_hazel': 0.2163265306122449,
#  'merlot_holly': 0.08571428571428572,
#  'merlot_lily': 0.16938775510204082,
#  'merlot_manchineel': 0.29183673469387755,
#  'merlot_marshmallow': 0.2326530612244898,
#  'mustard_burdock': 0.1469387755102041,
#  'mustard_foxglove': 0.2836734693877551,
#  'mustard_hepatica': 0.15918367346938778,
#  'mustard_hollyhock': 0.12040816326530614,
#  'mustard_myrtle': 0.1285714285714286,
#  'oat_arum': 0.46326530612244904,
#  'oat_borage': 0.2,
#  'oat_hazel': 0.25306122448979596,
#  'oat_hepatica': 0.4142857142857143,
#  'oat_hollow': 0.28163265306122454,
#  'oat_marigold': 0.1306122448979592,
#  'orange_acanthus': 0.12244897959183675,
#  'orange_broom': 0.39795918367346944,
#  'orange_hogbean': 0.17551020408163268,
#  'orange_hornbeam': 0.26734693877551025,
#  'orange_hyacinth': 0.18979591836734697,
#  'orange_lavender': 0.1326530612244898,
#  'oyster_marshmallow': 0.16938775510204082,
#  'oyster_myrtle': 0.35510204081632657,
#  'parchment_hibiscus': 0.3918367346938776,
#  'parchment_manchineel': 0.25510204081632654,
#  'parchment_marshmallow': 0.6428571428571429,
#  'parmesan_bramble': 0.1959183673469388,
#  'parmesan_helenium': 0.6959183673469388,
#  'parmesan_holly': 0.7775510204081634,
#  'parmesan_honeysuckle': 0.1326530612244898,
#  'parmesan_lily': 0.26734693877551025,
#  'parmesan_marshmallow': 0.3734693877551021,
#  'parmesan_mugwort': 0.2163265306122449,
#  'pearl_basil': 0.3489795918367347,
#  'pearl_heath': 0.2938775510204082,
#  'pearl_hepatica': 0.1795918367346939,
#  'pearl_larkspur': 0.07959183673469389,
#  'pineapple_ash': 0.0979591836734694,
#  'pineapple_barberry': 0.41836734693877553,
#  'pineapple_basil': 0.28571428571428575,
#  'pineapple_hazel': 0.3163265306122449,
#  'pineapple_honesty': 0.28775510204081634,
#  'porcelain_blackthorn': 0.5755102040816327,
#  'porcelain_foxglove': 0.20204081632653062,
#  'porcelain_hollyhock': 0.04693877551020409,
#  'porcelain_honesty': 0.3081632653061225,
#  'porcelain_laburnum': 0.11020408163265308,
#  'porcelain_mugwort': 0.5224489795918368,
#  'powder_basil': 0.1489795918367347,
#  'powder_honeysuckle': 0.1816326530612245,
#  'powder_mandrake': 0.20816326530612247,
#  'red_angelica': 0.2448979591836735,
#  'red_bugloss': 0.07142857142857144,
#  'red_honesty': 0.1795918367346939,
#  'red_marigold': 0.21020408163265308,
#  'rice_aloe': 0.45510204081632655,
#  'rice_ash': 0.44897959183673475,
#  'rice_basil': 0.3306122448979592,
#  'rice_fig': 0.1979591836734694,
#  'rice_hollyhock': 0.2469387755102041,
#  'rice_honesty': 0.25918367346938775,
#  'rice_lavender': 0.11836734693877551,
#  'rice_mistletoe': 0.2448979591836735,
#  'rose_acanthus': 0.46326530612244904,
#  'rose_bugloss': 0.1959183673469388,
#  'rose_fennel': 0.1673469387755102,
#  'rose_foxglove': 0.3306122448979592,
#  'rose_hedysarum': 0.29183673469387755,
#  'rose_hibiscus': 0.163265306122449,
#  'rose_lilac': 0.29183673469387755,
#  'rose_mistletoe': 0.2306122448979592,
#  'ruby_acacia': 0.35510204081632657,
#  'ruby_bugloss': 0.7102040816326531,
#  'ruby_hedysarum': 0.18775510204081636,
#  'ruby_hogbean': 0.1979591836734694,
#  'ruby_honeysuckle': 0.21836734693877552,
#  'ruby_lily': 0.21836734693877552,
#  'ruby_madder': 0.11836734693877551,
#  'ruby_manchineel': 0.40816326530612246,
#  'ruby_meadowsweet': 0.5346938775510205,
#  'ruby_motherwort': 0.20816326530612247,
#  'rust_aloe': 0.2979591836734694,
#  'rust_ash': 0.3285714285714286,
#  'rust_larkspur': 0.2448979591836735,
#  'salt_aloe': 0.2571428571428572,
#  'salt_bluebottle': 0.3020408163265306,
#  'salt_burdock': 0.17551020408163268,
#  'salt_manchineel': 0.18979591836734697,
#  'salt_myrtle': 0.1836734693877551,
#  'sand_acacia': 0.17755102040816328,
#  'sand_hepatica': 0.27346938775510204,
#  'sand_hornbeam': 0.21836734693877552,
#  'sand_marshmallow': 0.24285714285714288,
#  'sandcastle_acanthus': 0.1959183673469388,
#  'sandcastle_barberry': 0.23673469387755103,
#  'sandcastle_holly': 0.1326530612244898,
#  'sandcastle_madder': 0.1326530612244898,
#  'sandcastle_meadow': 0.34693877551020413,
#  'sandcastle_mezereon': 0.2326530612244898,
#  'sandcastle_mugwort': 0.12653061224489798,
#  'sandstone_acanthus': 0.1979591836734694,
#  'sandstone_amaranth': 0.12653061224489798,
#  'sandstone_hazel': 0.2469387755102041,
#  'sandstone_laurel': 0.09183673469387756,
#  'sandstone_lily': 0.17142857142857143,
#  'sangria_amaranth': 0.20612244897959187,
#  'sangria_bugloss': 0.2938775510204082,
#  'sangria_hepatica': 0.2,
#  'sangria_hortensia': 0.1979591836734694,
#  'sangria_larkspur': 0.12244897959183675,
#  'sangria_mezereon': 0.35714285714285715,
#  'scarlet_barberry': 0.27346938775510204,
#  'scarlet_broom': 0.28163265306122454,
#  'scarlet_fig': 0.23877551020408166,
#  'scarlet_holly': 0.014285714285714287,
#  'scarlet_honesty': 0.1653061224489796,
#  'scarlet_hortensia': 0.10408163265306124,
#  'sepia_basil': 0.2448979591836735,
#  'sepia_honesty': 0.2469387755102041,
#  'sepia_hortensia': 0.39795918367346944,
#  'sepia_mandrake': 0.33877551020408164,
#  'shortbread_hollyhock': 0.17142857142857143,
#  'shortbread_hornbeam': 0.13673469387755102,
#  'shortbread_laurel': 0.12244897959183675,
#  'shortbread_marvel': 0.0816326530612245,
#  'shortbread_milkwort': 0.24285714285714288,
#  'snow_borage': 0.29183673469387755,
#  'snow_fig': 0.07346938775510205,
#  'snow_hollyhock': 0.16938775510204082,
#  'snow_lilac': 0.1959183673469388,
#  'snow_marshmallow': 0.2306122448979592,
#  'snow_motherwort': 0.11020408163265308,
#  'spice_burdock': 0.29183673469387755,
#  'spice_fennel': 0.3408163265306123,
#  'spice_helenium': 0.15510204081632656,
#  'spice_hogbean': 0.4469387755102041,
#  'spice_marshmallow': 0.15714285714285717,
#  'spice_mezereon': 0.06122448979591837,
#  'spice_mugwort': 0.33877551020408164,
#  'squash_holly': 0.6510204081632653,
#  'squash_hyacinth': 0.19387755102040818,
#  'squash_manchineel': 0.06326530612244899,
#  'squash_milfoil': 0.46734693877551026,
#  'sugarcookie_borage': 0.1816326530612245,
#  'sugarcookie_bugloss': 0.22040816326530616,
#  'sugarcookie_lichen': 0.4102040816326531,
#  'tan_arum': 0.31428571428571433,
#  'tan_blackthorn': 0.0816326530612245,
#  'tan_lichen': 0.2142857142857143,
#  'tan_lucerne': 0.2755102040816327,
#  'tan_madder': 0.18775510204081636,
#  'tan_meadow': 0.22448979591836737,
#  'tangerine_hedysarum': 0.11224489795918369,
#  'tangerine_hepatica': 0.10612244897959185,
#  'tiger_basil': 0.20816326530612247,
#  'tiger_broom': 0.3408163265306123,
#  'tiger_larch': 0.1489795918367347,
#  'tiger_mezereon': 0.38367346938775515,
#  'white_angelica': 0.0816326530612245,
#  'white_fennel': 0.2163265306122449,
#  'white_hollyhock': 0.18979591836734697,
#  'white_larkspur': 0.22653061224489798,
#  'white_mandrake': 0.5795918367346939,
#  'white_milfoil': 0.2795918367346939,
#  'wine_arum': 0.46734693877551026,
#  'wine_marigold': 0.1469387755102041,
#  'wine_marvel': 0.19387755102040818,
#  'wine_milfoil': 0.2653061224489796,
#  'yam_ash': 0.2469387755102041,
#  'yam_blackthorn': 0.536734693877551,
#  'yam_bluebottle': 0.3285714285714286,
#  'yam_hedysarum': 0.35102040816326535,
#  'yam_hornbeam': 0.27346938775510204,
#  'yam_larch': 0.21836734693877552,
#  'yam_mistletoe': 0.22448979591836737,
#  'yam_mugwort': 0.1836734693877551,
#  'yellow_acanthus': 0.0673469387755102,
#  'yellow_amaranth': 0.2571428571428572,
#  'yellow_holly': 0.20204081632653062,
#  'yellow_honeysuckle': 0.1346938775510204,
#  'yellow_mezereon': 0.15306122448979592}

# %%
pos = nx.spring_layout(G)

nx.draw(G, pos, node_size = 5, width = 1)
plt.show()

# %%
# hint. for filtering, you can use Dictionary comprehension.
# ir works just like List comprehension but on tupples (key, value) pairs

some_accounts_degree = {'alabaster_acacia': 0.2693877551020408,
 'alabaster_foxglove': 0.16938775510204082,
 'alabaster_hepatica': 0.08979591836734695,
 'alabaster_marshmallow': 0.32040816326530613,
 'amber_aloe': 0.20816326530612247 }

high_degree_accounts = { key:value 
                         for (key,value) in some_accounts_degree.items()
                         if value > 0.2 }
high_degree_accounts
# Out:
# {'alabaster_acacia': 0.2693877551020408,
#  'alabaster_marshmallow': 0.32040816326530613,
#  'amber_aloe': 0.20816326530612247}
